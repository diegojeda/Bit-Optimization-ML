# %%
import pandas as pd
import numpy as np
from numpy import loadtxt
from pylab import *
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from IPython.core.interactiveshell import InteractiveShell  
InteractiveShell.ast_node_interactivity = "all"
from IPython.display import display, HTML
import pandas as pd
from scipy import stats
import pandas_profiling
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import missingno as msno
import pickle
from sklearn.preprocessing import LabelEncoder

# %%
url = "https://raw.githubusercontent.com/diegojeda/Curso-Analytics---Drilling-Bits/master/Dataset/BLCat.csv"

base = pd.read_csv(url,error_bad_lines=False)

# %%
from sklearn.model_selection import train_test_split

# Creamos las matrices para los modelos
X = base.drop('Log ROP', axis=1)
y = base[['Log ROP']]

# Dividimos los datos de manera aleatoria con el 25% para test y 75% para train
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=101)

# %%
# load the model from disk
loaded_model = pickle.load(open('svr_to_deploy.pkl', 'rb'))

# %%
feature_cols=base.drop('Log ROP', axis=1).columns

# %%
feature_cols
# Out:
# Index(['Unnamed: 0', 'Well', 'Size', 'Bit_Number', 'Re_Run', 'Reference',
#        'Type', 'Structure', 'Formation', 'Log Footage', 'Depth in',
#        'Depth out', 'Depth Average', 'Blades', 'Cutter size', 'Min Flow Rate',
#        'Max Flow Rate', 'TFA', 'HSI', 'Log Min WOB', 'Max WOB', 'Mud Weight',
#        'Drive_System', 'Min_RPM', 'Max_RPM', 'Torque Max', 'Torque Min',
#        'Manufacturer'],
#       dtype='object')

# %%
range(100,500,1)
# Out:
# range(100, 500)

# %%
from itertools import product

Size=[8.5]
Re_Run=["N"]
Type=["PDC"]
Structure=["Anticlinal P"]
Formation=["Mirador"]
Footage=[150]
Depth_Average=[15000]
Blades = [13]
Cutter_size=[11]
Min_FR= list(np.linspace(100,500,num=5))
Max_FR = list(np.linspace(500,1100,num=5))
TFA = list(np.linspace(1,5,num=5))
HSI = list(np.linspace(1,5,num=5))
Min_WOB = list(np.linspace(5, 30, num=6))
Max_WOB = list(np.linspace(30,55,num=6))
Mud_Weight=[10]
Drive_System=["RSS"]
Min_RPM = list(np.linspace(60,120,num=6))
Max_RPM = list(np.linspace(120,170,num=7))
T_Min =  list(np.linspace(5,25,num=5))
T_Max  = list(np.linspace(25,50,num=6))
Manufacturer=["Smith"]

'''
from itertools import product

Size=[8.5]
Re_Run=["N"]
Type=["PDC"]
Structure=["Anticlinal P"]
Formation=["Mirador"]
Footage=[150]
Depth_Average=[15000]
Blades = [13]
Cutter_size=[11]
Min_FR= range(100,500,10) # list(np.linspace(100,500,num=5))
Max_FR = range(500,1100,10) # list(np.linspace(500,1100,num=5))
TFA = [2] # list(np.linspace(1,5,num=5))
HSI = [2] #  list(np.linspace(1,5,num=5))
Min_WOB = [20] # list(np.linspace(5, 30, num=6))
Max_WOB = [50] # list(np.linspace(30,55,num=6))
Mud_Weight=[10]
Drive_System=["RSS"]
Min_RPM = [80] # list(np.linspace(60,120,num=6))
Max_RPM = [140] # list(np.linspace(120,170,num=7))
T_Min = [15] # list(np.linspace(5,25,num=5))
T_Max  = [30] # list(np.linspace(25,50,num=6))
Manufacturer=["Smith"]
'''

Data_exp=pd.DataFrame(list(product(Size,Re_Run,Type,Structure,Formation,Footage,Depth_Average,Blades,Cutter_size,Min_FR, Max_FR,TFA,HSI,Min_WOB,Max_WOB,Mud_Weight,Drive_System,Min_RPM,Max_RPM,T_Max,T_Min,Manufacturer)),
                 columns=["Size","Re_Run","Type","Structure","Formation","Footage","Depth Average","Blades","Cutter size","Min Flow Rate", "Max Flow Rate","TFA","HSI","Min WOB","Max WOB","Mud Weight","Drive_System","Min_RPM","Max_RPM","Torque Max","Torque Min","Manufacturer"])

Data_exp.iloc[0:10] # Primeras cinco filas
# Out:
# '\nfrom itertools import product\n\nSize=[8.5]\nRe_Run=["N"]\nType=["PDC"]\nStructure=["Anticlinal P"]\nFormation=["Mirador"]\nFootage=[150]\nDepth_Average=[15000]\nBlades = [13]\nCutter_size=[11]\nMin_FR= range(100,500,10) # list(np.linspace(100,500,num=5))\nMax_FR = range(500,1100,10) # list(np.linspace(500,1100,num=5))\nTFA = [2] # list(np.linspace(1,5,num=5))\nHSI = [2] #  list(np.linspace(1,5,num=5))\nMin_WOB = [20] # list(np.linspace(5, 30, num=6))\nMax_WOB = [50] # list(np.linspace(30,55,num=6))\nMud_Weight=[10]\nDrive_System=["RSS"]\nMin_RPM = [80] # list(np.linspace(60,120,num=6))\nMax_RPM = [140] # list(np.linspace(120,170,num=7))\nT_Min = [15] # list(np.linspace(5,25,num=5))\nT_Max  = [30] # list(np.linspace(25,50,num=6))\nManufacturer=["Smith"]\n'
#    Size Re_Run Type     Structure Formation  Footage  Depth Average  Blades  \
# 0   8.5      N  PDC  Anticlinal P   Mirador      150          15000      13
# 1   8.5      N  PDC  Anticlinal P   Mirador      150          15000      13
# 2   8.5      N  PDC  Anticlinal P   Mirador      150          15000      13
# 3   8.5      N  PDC  Anticlinal P   Mirador      150          15000      13
# 4   8.5      N  PDC  Anticlinal P   Mirador      150          15000      13
# 5   8.5      N  PDC  Anticlinal P   Mirador      150          15000      13
# 6   8.5      N  PDC  Anticlinal P   Mirador      150          15000      13
# 7   8.5      N  PDC  Anticlinal P   Mirador      150          15000      13
# 8   8.5      N  PDC  Anticlinal P   Mirador      150          15000      13
# 9   8.5      N  PDC  Anticlinal P   Mirador      150          15000      13
#
#    Cutter size  Min Flow Rate  ...  HSI  Min WOB  Max WOB  Mud Weight  \
# 0           11          100.0  ...  1.0      5.0     30.0          10
# 1           11          100.0  ...  1.0      5.0     30.0          10
# 2           11          100.0  ...  1.0      5.0     30.0          10
# 3           11          100.0  ...  1.0      5.0     30.0          10
# 4           11          100.0  ...  1.0      5.0     30.0          10
# 5           11          100.0  ...  1.0      5.0     30.0          10
# 6           11          100.0  ...  1.0      5.0     30.0          10
# 7           11          100.0  ...  1.0      5.0     30.0          10
# 8           11          100.0  ...  1.0      5.0     30.0          10
# 9           11          100.0  ...  1.0      5.0     30.0          10
#
#    Drive_System  Min_RPM Max_RPM  Torque Max  Torque Min  Manufacturer
# 0           RSS     60.0   120.0        25.0         5.0         Smith
# 1           RSS     60.0   120.0        25.0        10.0         Smith
# 2           RSS     60.0   120.0        25.0        15.0         Smith
# 3           RSS     60.0   120.0        25.0        20.0         Smith
# 4           RSS     60.0   120.0        25.0        25.0         Smith
# 5           RSS     60.0   120.0        30.0         5.0         Smith
# 6           RSS     60.0   120.0        30.0        10.0         Smith
# 7           RSS     60.0   120.0        30.0        15.0         Smith
# 8           RSS     60.0   120.0        30.0        20.0         Smith
# 9           RSS     60.0   120.0        30.0        25.0         Smith
#
# [10 rows x 22 columns]

# %%
Base_Frame = Data_exp.copy()
Base_Frame.columns
# Out:
# Index(['Size', 'Re_Run', 'Type', 'Structure', 'Formation', 'Footage',
#        'Depth Average', 'Blades', 'Cutter size', 'Min Flow Rate',
#        'Max Flow Rate', 'TFA', 'HSI', 'Min WOB', 'Max WOB', 'Mud Weight',
#        'Drive_System', 'Min_RPM', 'Max_RPM', 'Torque Max', 'Torque Min',
#        'Manufacturer'],
#       dtype='object')

# %%
Data_exp
# Out:
#           Size Re_Run Type     Structure Formation  Footage  Depth Average  \
# 0          8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 1          8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 2          8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 3          8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 4          8.5      N  PDC  Anticlinal P   Mirador      150          15000
# ...        ...    ...  ...           ...       ...      ...            ...
# 28349995   8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 28349996   8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 28349997   8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 28349998   8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 28349999   8.5      N  PDC  Anticlinal P   Mirador      150          15000
#
#           Blades  Cutter size  Min Flow Rate  ...  HSI  Min WOB  Max WOB  \
# 0             13           11          100.0  ...  1.0      5.0     30.0
# 1             13           11          100.0  ...  1.0      5.0     30.0
# 2             13           11          100.0  ...  1.0      5.0     30.0
# 3             13           11          100.0  ...  1.0      5.0     30.0
# 4             13           11          100.0  ...  1.0      5.0     30.0
# ...          ...          ...            ...  ...  ...      ...      ...
# 28349995      13           11          500.0  ...  5.0     30.0     55.0
# 28349996      13           11          500.0  ...  5.0     30.0     55.0
# 28349997      13           11          500.0  ...  5.0     30.0     55.0
# 28349998      13           11          500.0  ...  5.0     30.0     55.0
# 28349999      13           11          500.0  ...  5.0     30.0     55.0
#
#           Mud Weight  Drive_System  Min_RPM Max_RPM  Torque Max  Torque Min  \
# 0                 10           RSS     60.0   120.0        25.0         5.0
# 1                 10           RSS     60.0   120.0        25.0        10.0
# 2                 10           RSS     60.0   120.0        25.0        15.0
# 3                 10           RSS     60.0   120.0        25.0        20.0
# 4                 10           RSS     60.0   120.0        25.0        25.0
# ...              ...           ...      ...     ...         ...         ...
# 28349995          10           RSS    120.0   170.0        50.0         5.0
# 28349996          10           RSS    120.0   170.0        50.0        10.0
# 28349997          10           RSS    120.0   170.0        50.0        15.0
# 28349998          10           RSS    120.0   170.0        50.0        20.0
# 28349999          10           RSS    120.0   170.0        50.0        25.0
#
#           Manufacturer
# 0                Smith
# 1                Smith
# 2                Smith
# 3                Smith
# 4                Smith
# ...                ...
# 28349995         Smith
# 28349996         Smith
# 28349997         Smith
# 28349998         Smith
# 28349999         Smith
#
# [28350000 rows x 22 columns]

# %%
Data_exp.Footage=np.log(Data_exp.Footage)

Data_exp["Min WOB"]=np.log(Data_exp["Min WOB"])

Data_exp = Data_exp.rename(columns = {"Footage":"Log Footage",
                              "Min WOB":"Log Min WOB"})

Data_exp.tail()
# Out:
#           Size Re_Run Type     Structure Formation  Log Footage  \
# 28349995   8.5      N  PDC  Anticlinal P   Mirador     5.010635
# 28349996   8.5      N  PDC  Anticlinal P   Mirador     5.010635
# 28349997   8.5      N  PDC  Anticlinal P   Mirador     5.010635
# 28349998   8.5      N  PDC  Anticlinal P   Mirador     5.010635
# 28349999   8.5      N  PDC  Anticlinal P   Mirador     5.010635
#
#           Depth Average  Blades  Cutter size  Min Flow Rate  ...  HSI  \
# 28349995          15000      13           11          500.0  ...  5.0
# 28349996          15000      13           11          500.0  ...  5.0
# 28349997          15000      13           11          500.0  ...  5.0
# 28349998          15000      13           11          500.0  ...  5.0
# 28349999          15000      13           11          500.0  ...  5.0
#
#           Log Min WOB  Max WOB  Mud Weight  Drive_System  Min_RPM Max_RPM  \
# 28349995     3.401197     55.0          10           RSS    120.0   170.0
# 28349996     3.401197     55.0          10           RSS    120.0   170.0
# 28349997     3.401197     55.0          10           RSS    120.0   170.0
# 28349998     3.401197     55.0          10           RSS    120.0   170.0
# 28349999     3.401197     55.0          10           RSS    120.0   170.0
#
#           Torque Max  Torque Min  Manufacturer
# 28349995        50.0         5.0         Smith
# 28349996        50.0        10.0         Smith
# 28349997        50.0        15.0         Smith
# 28349998        50.0        20.0         Smith
# 28349999        50.0        25.0         Smith
#
# [5 rows x 22 columns]

# %%
base = base.drop(['Log ROP',"Depth out","Depth in","Bit_Number","Reference","Well","Unnamed: 0"],axis=1)

# %%
base
# Out:
#      Size Re_Run     Type     Structure  Formation  Log Footage  \
# 0    36.0      N  Tricone  Anticlinal N         C5     4.406719
# 1    26.0      N  Tricone  Anticlinal N         C5     2.708050
# 2    26.0      R  Tricone  Anticlinal N         C5     6.563856
# 3    26.0      R  Tricone  Anticlinal N         C6     6.304449
# 4    26.0      N  Tricone  Anticlinal N         C6     6.082219
# ..    ...    ...      ...           ...        ...          ...
# 207   8.5      N      PDC  Anticlinal F  Guadalupe     5.389072
# 208   8.5      N      PDC  Anticlinal F  Guadalupe     4.574711
# 209   8.5      N      PDC  Anticlinal F  Guadalupe     5.288267
# 210   8.5      N      PDC  Anticlinal F  Guadalupe     4.025352
# 211   8.5      N      PDC  Anticlinal F    Gacheta     4.595120
#
#      Depth Average  Blades  Cutter size  Min Flow Rate  ...       HSI  \
# 0             90.0     3.0          0.0          430.0  ...  0.001451
# 1            138.5     3.0          0.0          540.0  ...  0.085069
# 2            774.0     3.0          0.0          580.0  ...  0.500000
# 3            774.0     3.0          0.0          580.0  ...  0.500000
# 4           1821.5     3.0          0.0          900.0  ...  0.842000
# ..             ...     ...          ...            ...  ...       ...
# 207        14120.5     7.0         13.0          560.0  ...  4.300000
# 208        14278.5     8.0         13.0          600.0  ...  4.400000
# 209        14426.0     8.0         13.0          300.0  ...  2.400000
# 210        14602.5     8.0         13.0          300.0  ...  5.500000
# 211        14602.5     8.0         13.0          300.0  ...  5.500000
#
#      Log Min WOB  Max WOB  Mud Weight  Drive_System  Min_RPM Max_RPM  \
# 0       1.609438     13.0         8.5        Rotary     60.0    80.0
# 1       2.890372     23.0         8.5        Rotary     48.0    48.0
# 2       3.218876     78.0         8.5           RSS     47.0    73.0
# 3       3.218876     78.0         8.5           RSS     47.0    73.0
# 4       3.688879     55.0         9.6           RSS    144.0   168.0
# ..           ...      ...         ...           ...      ...     ...
# 207     2.708050     30.0         8.2        Rotary     90.0   120.0
# 208     2.251292     45.0         8.2        Rotary     78.0   115.0
# 209     1.609438     35.0         8.3        Rotary     90.0   130.0
# 210     2.251292     30.0         8.4        Rotary     50.0   135.0
# 211     2.017700     30.0         8.4        Rotary     50.0   135.0
#
#      Torque Max  Torque Min  Manufacturer
# 0           5.0         3.0         Varel
# 1          15.0         2.0       Hycalog
# 2          15.0         2.0       Hycalog
# 3          15.0         2.0       Hycalog
# 4          15.0         2.0        Hughes
# ..          ...         ...           ...
# 207         8.0         6.0   Halliburton
# 208         9.0         7.0        Hughes
# 209         9.0         7.0         Smith
# 210         8.5         7.0         Smith
# 211         8.5         7.0         Smith
#
# [212 rows x 22 columns]

# %%
base_exp_pred=base.append(Data_exp)

# %%
base_exp_pred
# Out:
#           Size Re_Run     Type     Structure Formation  Log Footage  \
# 0         36.0      N  Tricone  Anticlinal N        C5     4.406719
# 1         26.0      N  Tricone  Anticlinal N        C5     2.708050
# 2         26.0      R  Tricone  Anticlinal N        C5     6.563856
# 3         26.0      R  Tricone  Anticlinal N        C6     6.304449
# 4         26.0      N  Tricone  Anticlinal N        C6     6.082219
# ...        ...    ...      ...           ...       ...          ...
# 28349995   8.5      N      PDC  Anticlinal P   Mirador     5.010635
# 28349996   8.5      N      PDC  Anticlinal P   Mirador     5.010635
# 28349997   8.5      N      PDC  Anticlinal P   Mirador     5.010635
# 28349998   8.5      N      PDC  Anticlinal P   Mirador     5.010635
# 28349999   8.5      N      PDC  Anticlinal P   Mirador     5.010635
#
#           Depth Average  Blades  Cutter size  Min Flow Rate  ...       HSI  \
# 0                  90.0     3.0          0.0          430.0  ...  0.001451
# 1                 138.5     3.0          0.0          540.0  ...  0.085069
# 2                 774.0     3.0          0.0          580.0  ...  0.500000
# 3                 774.0     3.0          0.0          580.0  ...  0.500000
# 4                1821.5     3.0          0.0          900.0  ...  0.842000
# ...                 ...     ...          ...            ...  ...       ...
# 28349995        15000.0    13.0         11.0          500.0  ...  5.000000
# 28349996        15000.0    13.0         11.0          500.0  ...  5.000000
# 28349997        15000.0    13.0         11.0          500.0  ...  5.000000
# 28349998        15000.0    13.0         11.0          500.0  ...  5.000000
# 28349999        15000.0    13.0         11.0          500.0  ...  5.000000
#
#           Log Min WOB  Max WOB  Mud Weight  Drive_System  Min_RPM Max_RPM  \
# 0            1.609438     13.0         8.5        Rotary     60.0    80.0
# 1            2.890372     23.0         8.5        Rotary     48.0    48.0
# 2            3.218876     78.0         8.5           RSS     47.0    73.0
# 3            3.218876     78.0         8.5           RSS     47.0    73.0
# 4            3.688879     55.0         9.6           RSS    144.0   168.0
# ...               ...      ...         ...           ...      ...     ...
# 28349995     3.401197     55.0        10.0           RSS    120.0   170.0
# 28349996     3.401197     55.0        10.0           RSS    120.0   170.0
# 28349997     3.401197     55.0        10.0           RSS    120.0   170.0
# 28349998     3.401197     55.0        10.0           RSS    120.0   170.0
# 28349999     3.401197     55.0        10.0           RSS    120.0   170.0
#
#           Torque Max  Torque Min  Manufacturer
# 0                5.0         3.0         Varel
# 1               15.0         2.0       Hycalog
# 2               15.0         2.0       Hycalog
# 3               15.0         2.0       Hycalog
# 4               15.0         2.0        Hughes
# ...              ...         ...           ...
# 28349995        50.0         5.0         Smith
# 28349996        50.0        10.0         Smith
# 28349997        50.0        15.0         Smith
# 28349998        50.0        20.0         Smith
# 28349999        50.0        25.0         Smith
#
# [28350212 rows x 22 columns]

# %%
# Verificamos las categorias de cada variable categorica
print(base_exp_pred.Re_Run.unique())
print(base_exp_pred.Type.unique())
print(base_exp_pred.Structure.unique())
print(base_exp_pred.Formation.unique())
print(base_exp_pred.Drive_System.unique())
print(base_exp_pred.Manufacturer.unique())
# Out:
# ['N' 'R' 'RR' 'R4' 'R5']
# ['Tricone' 'PDC' 'Impregnated' 'Hybrid']
# ['Anticlinal N' 'Anticlinal M' 'Anticlinal F' 'Anticlinal P' 'Imbricate'
#  'Anticlinal G' 'Anticlinal D']
# ['C5' 'C6' 'C7' 'C8' 'Mirador' 'Los Cuervos' 'Barco' 'Guadalupe'
#  'Colluvium' 'C2' 'C3' 'C4' 'Guayabo' 'Charte' 'Leon' 'C1' 'Sltn Market'
#  'Guad. Shale' 'Guad. Upper' 'Gacheta']
# ['Rotary' 'RSS' 'Turbine' 'Motor']
# ['Varel' 'Hycalog' 'Hughes' 'Security' 'Smith' 'Halliburton']

# %%
# Identificamos las etiquetas de las categorias
categorical_features = ['Re_Run', 'Type', 'Structure',"Formation","Drive_System","Manufacturer"]

le = LabelEncoder()

# Convert the variables to numerical
for i in range(6):
    new = le.fit_transform(base_exp_pred[categorical_features[i]])
    base_exp_pred[categorical_features[i]] = new

# %%
base_exp_pred.tail()
# Out:
#           Size  Re_Run  Type  Structure  Formation  Log Footage  \
# 28349995   8.5       0     2          5         18     5.010635
# 28349996   8.5       0     2          5         18     5.010635
# 28349997   8.5       0     2          5         18     5.010635
# 28349998   8.5       0     2          5         18     5.010635
# 28349999   8.5       0     2          5         18     5.010635
#
#           Depth Average  Blades  Cutter size  Min Flow Rate  ...  HSI  \
# 28349995        15000.0    13.0         11.0          500.0  ...  5.0
# 28349996        15000.0    13.0         11.0          500.0  ...  5.0
# 28349997        15000.0    13.0         11.0          500.0  ...  5.0
# 28349998        15000.0    13.0         11.0          500.0  ...  5.0
# 28349999        15000.0    13.0         11.0          500.0  ...  5.0
#
#           Log Min WOB  Max WOB  Mud Weight  Drive_System  Min_RPM  Max_RPM  \
# 28349995     3.401197     55.0        10.0             1    120.0    170.0
# 28349996     3.401197     55.0        10.0             1    120.0    170.0
# 28349997     3.401197     55.0        10.0             1    120.0    170.0
# 28349998     3.401197     55.0        10.0             1    120.0    170.0
# 28349999     3.401197     55.0        10.0             1    120.0    170.0
#
#           Torque Max  Torque Min  Manufacturer
# 28349995        50.0         5.0             4
# 28349996        50.0        10.0             4
# 28349997        50.0        15.0             4
# 28349998        50.0        20.0             4
# 28349999        50.0        25.0             4
#
# [5 rows x 22 columns]

# %%
# Importamos librerias para escalar los datos, dividir el dataset y traer el modelo
from sklearn.preprocessing import StandardScaler

# Escalamos los datos
scaler = StandardScaler()
scaler.fit(base_exp_pred)
base_exp_pred = scaler.transform(base_exp_pred)
base_exp_pred
# Out:
# StandardScaler()
# array([[ 1.33416461e+03, -9.03773634e-04,  7.05246083e+02, ...,
#         -3.80589183e+00, -1.69704660e+00,  1.72570092e+02],
#        [ 8.49013301e+02, -9.03773634e-04,  7.05246083e+02, ...,
#         -2.63484182e+00, -1.83846779e+00, -3.45134231e+02],
#        [ 8.49013301e+02,  4.13259969e+02,  7.05246083e+02, ...,
#         -2.63484182e+00, -1.83846779e+00, -3.45134231e+02],
#        ...,
#        [-1.49501639e-03, -9.03773634e-04, -7.46286651e-05, ...,
#          1.46383322e+00,  7.61982623e-06,  1.98436622e-03],
#        [-1.49501639e-03, -9.03773634e-04, -7.46286651e-05, ...,
#          1.46383322e+00,  7.07113547e-01,  1.98436622e-03],
#        [-1.49501639e-03, -9.03773634e-04, -7.46286651e-05, ...,
#          1.46383322e+00,  1.41421947e+00,  1.98436622e-03]])

# %%
len(Data_exp)

Data_List_Pred=base_exp_pred[-(len(Data_exp)+1):-1]
# Out:
# 28350000

# %%
y_pred_rfs = loaded_model.predict(Data_List_Pred)
R_final = pd.DataFrame(np.exp(y_pred_rfs))
R_final.columns = ["ROP"]
#R_final
Max_ROP=max(np.exp(y_pred_rfs))
Indice=R_final.loc[R_final.ROP==Max_ROP].index
#Max_ROP
#Indice
P_Opt=Data_exp.iloc[Indice].T
#P_Opt

# %%
P_Opt=Data_exp.iloc[Indice].T

# %%
P_Opt

print("La ROP Max alcanzada con estos parametros es: %.3f (ft/hr)" %(Max_ROP))
# Out:
#                    27995127
# Size                    8.5
# Re_Run                    N
# Type                    PDC
# Structure      Anticlinal P
# Formation           Mirador
# Log Footage         5.01064
# Depth Average         15000
# Blades                   13
# Cutter size              11
# Min Flow Rate           500
# Max Flow Rate          1100
# TFA                       4
# HSI                       3
# Log Min WOB         2.30259
# Max WOB                  30
# Mud Weight               10
# Drive_System            RSS
# Min_RPM                  84
# Max_RPM                 120
# Torque Max               50
# Torque Min               15
# Manufacturer          Smith
# La ROP Max alcanzada con estos parametros es: 34.890 (ft/hr)

# %%
Base_Frame["ROP Predict"] = np.exp(y_pred_rfs)

# %%
Base_Frame
# Out:
#       Size Re_Run Type     Structure Formation  Footage  Depth Average  \
# 0      8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 1      8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 2      8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 3      8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 4      8.5      N  PDC  Anticlinal P   Mirador      150          15000
# ...    ...    ...  ...           ...       ...      ...            ...
# 2395   8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 2396   8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 2397   8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 2398   8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 2399   8.5      N  PDC  Anticlinal P   Mirador      150          15000
#
#       Blades  Cutter size  Min Flow Rate  ...  Min WOB  Max WOB  Mud Weight  \
# 0         13           11            100  ...       20       50          10
# 1         13           11            100  ...       20       50          10
# 2         13           11            100  ...       20       50          10
# 3         13           11            100  ...       20       50          10
# 4         13           11            100  ...       20       50          10
# ...      ...          ...            ...  ...      ...      ...         ...
# 2395      13           11            490  ...       20       50          10
# 2396      13           11            490  ...       20       50          10
# 2397      13           11            490  ...       20       50          10
# 2398      13           11            490  ...       20       50          10
# 2399      13           11            490  ...       20       50          10
#
#       Drive_System  Min_RPM  Max_RPM Torque Max  Torque Min  Manufacturer  \
# 0              RSS       80      140         30          15         Smith
# 1              RSS       80      140         30          15         Smith
# 2              RSS       80      140         30          15         Smith
# 3              RSS       80      140         30          15         Smith
# 4              RSS       80      140         30          15         Smith
# ...            ...      ...      ...        ...         ...           ...
# 2395           RSS       80      140         30          15         Smith
# 2396           RSS       80      140         30          15         Smith
# 2397           RSS       80      140         30          15         Smith
# 2398           RSS       80      140         30          15         Smith
# 2399           RSS       80      140         30          15         Smith
#
#       ROP Predict
# 0        6.921475
# 1        4.032532
# 2        4.036876
# 3        4.042092
# 4        4.048187
# ...           ...
# 2395    11.792185
# 2396    11.917171
# 2397    12.040633
# 2398    12.162402
# 2399    12.282305
#
# [2400 rows x 23 columns]

# %%
Base_Frame.columns
# Out:
# Index(['Size', 'Re_Run', 'Type', 'Structure', 'Formation', 'Footage',
#        'Depth Average', 'Blades', 'Cutter size', 'Min Flow Rate',
#        'Max Flow Rate', 'TFA', 'HSI', 'Min WOB', 'Max WOB', 'Mud Weight',
#        'Drive_System', 'Min_RPM', 'Max_RPM', 'Torque Max', 'Torque Min',
#        'Manufacturer', 'ROP Predict'],
#       dtype='object')

# %%
Test=Base_Frame[#(Base_Frame["Min Flow Rate"]==200)&
                #(Base_Frame["Max Flow Rate"]==800)&
                (Base_Frame["TFA"]==2)&
                (Base_Frame["HSI"]==2)&
                (Base_Frame["Min WOB"]==20)&
                (Base_Frame["Max WOB"]==50)&
                (Base_Frame["Min_RPM"]==80)&
                (Base_Frame["Max_RPM"]==140)&
                (Base_Frame["Torque Min"]==15)&
                (Base_Frame["Torque Max"]==30)
               ]

Test
# Out:
#       Size Re_Run Type     Structure Formation  Footage  Depth Average  \
# 0      8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 1      8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 2      8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 3      8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 4      8.5      N  PDC  Anticlinal P   Mirador      150          15000
# ...    ...    ...  ...           ...       ...      ...            ...
# 2395   8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 2396   8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 2397   8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 2398   8.5      N  PDC  Anticlinal P   Mirador      150          15000
# 2399   8.5      N  PDC  Anticlinal P   Mirador      150          15000
#
#       Blades  Cutter size  Min Flow Rate  ...  Min WOB  Max WOB  Mud Weight  \
# 0         13           11            100  ...       20       50          10
# 1         13           11            100  ...       20       50          10
# 2         13           11            100  ...       20       50          10
# 3         13           11            100  ...       20       50          10
# 4         13           11            100  ...       20       50          10
# ...      ...          ...            ...  ...      ...      ...         ...
# 2395      13           11            490  ...       20       50          10
# 2396      13           11            490  ...       20       50          10
# 2397      13           11            490  ...       20       50          10
# 2398      13           11            490  ...       20       50          10
# 2399      13           11            490  ...       20       50          10
#
#       Drive_System  Min_RPM  Max_RPM Torque Max  Torque Min  Manufacturer  \
# 0              RSS       80      140         30          15         Smith
# 1              RSS       80      140         30          15         Smith
# 2              RSS       80      140         30          15         Smith
# 3              RSS       80      140         30          15         Smith
# 4              RSS       80      140         30          15         Smith
# ...            ...      ...      ...        ...         ...           ...
# 2395           RSS       80      140         30          15         Smith
# 2396           RSS       80      140         30          15         Smith
# 2397           RSS       80      140         30          15         Smith
# 2398           RSS       80      140         30          15         Smith
# 2399           RSS       80      140         30          15         Smith
#
#       ROP Predict
# 0        6.921475
# 1        4.032532
# 2        4.036876
# 3        4.042092
# 4        4.048187
# ...           ...
# 2395    11.792185
# 2396    11.917171
# 2397    12.040633
# 2398    12.162402
# 2399    12.282305
#
# [2400 rows x 23 columns]

# %%
Tabla=Test.pivot(index="Min Flow Rate",columns="Max Flow Rate",values="ROP Predict")
print(Tabla)
# Out:
# Max Flow Rate       500       510       520       530       540       550   \
# Min Flow Rate
# 100             6.921475  4.032532  4.036876  4.042092  4.048187  4.055167
# 110             5.797769  4.052834  4.057952  4.063958  4.070859  4.078660
# 120             5.888349  4.074888  4.080806  4.087628  4.095361  4.104012
# 130             5.983031  4.098709  4.105453  4.113118  4.121711  4.131240
# 140             6.081886  4.124312  4.131909  4.140445  4.149927  4.160362
# 150             6.184985  4.151711  4.160189  4.169624  4.180024  4.191396
# 160             6.292393  4.180919  4.190306  4.200670  4.212017  4.224356
# 170             6.404172  4.211948  4.222274  4.233596  4.245921  4.259257
# 180             6.520382  4.244809  4.256103  4.268413  4.281747  4.296113
# 190             6.641073  4.279513  4.291805  4.305134  4.319508  4.334936
# 200             6.766294  4.316067  4.329388  4.343767  4.359214  4.375736
# 210             6.896085  4.354479  4.368860  4.384322  4.400873  4.418524
# 220             7.030479  4.394755  4.410227  4.426803  4.444493  4.463306
# 230             7.169500  4.436898  4.453494  4.471217  4.490079  4.510088
# 240             7.313165  4.480911  4.498662  4.517566  4.537633  4.558874
# 250             7.461481  4.526792  4.545732  4.565850  4.587157  4.609664
# 260             7.614441  4.574541  4.594702  4.616068  4.638650  4.662458
# 270             7.772032  4.624153  4.645568  4.668216  4.692107  4.717253
# 280             7.934224  4.675621  4.698323  4.722286  4.747522  4.774041
# 290             8.100976  4.728934  4.752957  4.778270  4.804885  4.832812
# 300             8.272231  4.784082  4.809459  4.836155  4.864183  4.893555
# 310             8.447919  4.841048  4.867812  4.895925  4.925402  4.956253
# 320             8.627953  4.899814  4.927997  4.957561  4.988520  5.020887
# 330             8.812229  4.960358  4.989992  5.021040  5.053516  5.087432
# 340             9.000626  5.022654  5.053772  5.086337  5.120362  5.155861
# 350             9.193003  5.086674  5.119307  5.153420  5.189027  5.226143
# 360             9.389203  5.152385  5.186563  5.222255  5.259476  5.298241
# 370             9.589047  5.219751  5.255503  5.292804  5.331669  5.372115
# 380             9.792336  5.288730  5.326084  5.365023  5.405563  5.447720
# 390             9.998852  5.359277  5.398261  5.438866  5.481109  5.525005
# 400            10.208356  5.431343  5.471983  5.514280  5.558253  5.603916
# 410            10.420587  5.504875  5.547194  5.591209  5.636936  5.684392
# 420            10.635262  5.579813  5.623836  5.669590  5.717095  5.766368
# 430            10.852080  5.656096  5.701842  5.749357  5.798662  5.849772
# 440            11.070717  5.733656  5.781143  5.830439  5.881562  5.934531
# 450            11.290830  5.812421  5.861667  5.912759  5.965718  6.020561
# 460            11.512055  5.892313  5.943332  5.996236  6.051044  6.107777
# 470            11.734010  5.973253  6.026056  6.080783  6.137453  6.196086
# 480            11.956296  6.055154  6.109750  6.166309  6.224849  6.285391
# 490            12.178494  6.137925  6.194321  6.252717  6.313134  6.375591
#
# Max Flow Rate      560       570       580       590   ...       1000  \
# Min Flow Rate                                          ...
# 100            4.063037  4.071804  4.081472  4.092047  ...   5.309486
# 110            4.087368  4.096989  4.107529  4.118992  ...   5.386334
# 120            4.113586  4.124091  4.135531  4.147912  ...   5.466872
# 130            4.141710  4.153127  4.165498  4.178828  ...   5.551169
# 140            4.171757  4.184118  4.197451  4.211762  ...   5.639287
# 150            4.203746  4.217081  4.231408  4.246732  ...   5.731290
# 160            4.237692  4.252034  4.267387  4.283757  ...   5.827235
# 170            4.273612  4.288992  4.305404  4.322855  ...   5.927180
# 180            4.311518  4.327970  4.345476  4.364042  ...   6.031176
# 190            4.351425  4.368982  4.387616  4.407333  ...   6.139271
# 200            4.393343  4.412041  4.431838  4.452741  ...   6.251507
# 210            4.437282  4.457155  4.478151  4.500278  ...   6.367921
# 220            4.483250  4.504334  4.526566  4.549953  ...   6.488544
# 230            4.531254  4.553584  4.577089  4.601774  ...   6.613399
# 240            4.581296  4.604911  4.629725  4.655747  ...   6.742503
# 250            4.633380  4.658314  4.684476  4.711873  ...   6.875862
# 260            4.687504  4.713795  4.741342  4.770154  ...   7.013474
# 270            4.743664  4.771350  4.800321  4.830585  ...   7.155328
# 280            4.801854  4.830972  4.861405  4.893161  ...   7.301401
# 290            4.862065  4.892652  4.924585  4.957873  ...   7.451658
# 300            4.924283  4.956377  4.989848  5.024707  ...   7.606052
# 310            4.988492  5.022130  5.057178  5.093645  ...   7.764524
# 320            5.054673  5.089891  5.126553  5.164667  ...   7.926999
# 330            5.122801  5.159636  5.197948  5.237748  ...   8.093389
# 340            5.192848  5.231335  5.271334  5.312857  ...   8.263589
# 350            5.264781  5.304955  5.346677  5.389959  ...   8.437480
# 360            5.338564  5.380459  5.423939  5.469014  ...   8.614925
# 370            5.414156  5.457804  5.503074  5.549977  ...   8.795769
# 380            5.491508  5.536942  5.584034  5.632798  ...   8.979841
# 390            5.570571  5.617819  5.666765  5.717421  ...   9.166952
# 400            5.651286  5.700378  5.751207  5.803783  ...   9.356893
# 410            5.733593  5.784556  5.837293  5.891818  ...   9.549439
# 420            5.817424  5.870281  5.924952  5.981451  ...   9.744343
# 430            5.902707  5.957480  6.014108  6.072603  ...   9.941342
# 440            5.989362  6.046072  6.104676  6.165188  ...  10.140154
# 450            6.077306  6.135970  6.196568  6.259115  ...  10.340480
# 460            6.166450  6.227083  6.289689  6.354284  ...  10.542001
# 470            6.256700  6.319312  6.383938  6.450593  ...  10.744383
# 480            6.347954  6.412554  6.479209  6.547931  ...  10.947275
# 490            6.440107  6.506701  6.575388  6.646182  ...  11.150312
#
# Max Flow Rate       1010       1020       1030       1040       1050  \
# Min Flow Rate
# 100             5.356153   5.403384   5.451148   5.499416   5.548157
# 110             5.434412   5.483049   5.532215   5.581877   5.632003
# 120             5.516407   5.566496   5.617106   5.668205   5.719758
# 130             5.602206   5.653791   5.705891   5.758470   5.811492
# 140             5.691873   5.745001   5.798635   5.852738   5.907272
# 150             5.785472   5.840188   5.895402   5.951074   6.007164
# 160             5.883061   5.939414   5.996254   6.053540   6.111230
# 170             5.984699   6.042735   6.101247   6.160193   6.219527
# 180             6.090436   6.150204   6.210435   6.271086   6.332108
# 190             6.200322   6.261869   6.323867   6.386267   6.449022
# 200             6.314398   6.377773   6.441583   6.505780   6.570311
# 210             6.432701   6.497952   6.563622   6.629661   6.696012
# 220             6.555262   6.622437   6.690014   6.757938   6.826153
# 230             6.682105   6.751250   6.820779   6.890634   6.960755
# 240             6.813244   6.884406   6.955933   7.027761   7.099830
# 250             6.948685   7.021911   7.095479   7.169324   7.243381
# 260             7.088426   7.163761   7.239413   7.315315   7.391399
# 270             7.232454   7.309940   7.387718   7.465717   7.543866
# 280             7.380744   7.460423   7.540367   7.620501   7.700750
# 290             7.533261   7.615172   7.697319   7.779624   7.862008
# 300             7.689954   7.774136   7.858522   7.943031   8.027580
# 310             7.850761   7.937250   8.023908   8.110652   8.197395
# 320             8.015607   8.104434   8.193395   8.282402   8.371364
# 330             8.184399   8.275594   8.366885   8.458179   8.549384
# 340             8.357030   8.450619   8.544264   8.637867   8.731332
# 350             8.533376   8.629382   8.725400   8.821330   8.917070
# 360             8.713296   8.811737   8.910145   9.008415   9.106441
# 370             8.896633   8.997523   9.098331   9.198951   9.299269
# 380             9.083210   9.186558   9.289775   9.392747   9.495360
# 390             9.272832   9.378642   9.484269   9.589595   9.694498
# 400             9.465286   9.573558   9.681592   9.789264   9.896449
# 410             9.660340   9.771068   9.881499   9.991506  10.100959
# 420             9.857743   9.970915  10.083729  10.196053  10.307753
# 430            10.057226  10.172823  10.287999  10.402617  10.516538
# 440            10.258499  10.376497  10.494007  10.610889  10.727000
# 450            10.461257  10.581623  10.701435  10.820545  10.938805
# 460            10.665175  10.787872  10.909944  11.031239  11.151604
# 470            10.869911  10.994894  11.119179  11.242609  11.365026
# 480            11.075107  11.202324  11.328767  11.454276  11.578687
# 490            11.280391  11.409782  11.538322  11.665845  11.792185
#
# Max Flow Rate       1060       1070       1080       1090
# Min Flow Rate
# 100             5.597337   5.646924   5.696882   5.747176
# 110             5.682558   5.733507   5.784813   5.836440
# 120             5.771728   5.824079   5.876773   5.929770
# 130             5.864919   5.918712   5.972832   6.027238
# 140             5.962198   6.017475   6.073060   6.128912
# 150             6.063631   6.120432   6.177523   6.234859
# 160             6.169281   6.227647   6.286283   6.345141
# 170             6.279204   6.339177   6.399397   6.459816
# 180             6.393454   6.455076   6.516921   6.578938
# 190             6.512081   6.575391   6.638900   6.702553
# 200             6.635125   6.700165   6.765377   6.830703
# 210             6.762622   6.829432   6.896386   6.963421
# 220             6.894601   6.963221   7.031953   7.100734
# 230             7.031082   7.101551   7.172098   7.242659
# 240             7.172075   7.244431   7.316829   7.389202
# 250             7.317583   7.391861   7.466145   7.540363
# 260             7.467595   7.543831   7.620032   7.696125
# 270             7.622091   7.700318   7.778468   7.856463
# 280             7.781038   7.861286   7.941413   8.021337
# 290             7.944390   8.026688   8.108818   8.190695
# 300             8.112085   8.196460   8.280617   8.364467
# 310             8.284049   8.370524   8.456729   8.542570
# 320             8.460190   8.548786   8.637056   8.724903
# 330             8.640401   8.731134   8.821484   8.911348
# 340             8.824557   8.917441   9.009880   9.101770
# 350             9.012515   9.107560   9.202095   9.296013
# 360             9.204114   9.301324   9.397959   9.493904
# 370             9.399174   9.498551   9.597282   9.695250
# 380             9.597495   9.699034   9.799854   9.899835
# 390             9.798857   9.902549  10.005447  10.107425
# 400            10.003021  10.108851  10.213810  10.317765
# 410            10.209727  10.317676  10.424672  10.530579
# 420            10.418694  10.528736  10.637741  10.745569
# 430            10.629622  10.741726  10.852706  10.962418
# 440            10.842193  10.956321  11.069236  11.180789
# 450            11.056066  11.172174  11.286977  11.400322
# 460            11.270884  11.388922  11.505561  11.620643
# 470            11.486271  11.606183  11.724599  11.841358
# 480            11.701836  11.823558  11.943686  12.062054
# 490            11.917171  12.040633  12.162402  12.282305
#
# [40 rows x 60 columns]

# %%
Test["Min Flow Rate"].max()
# Out:
# 490

# %%
fig, ax = plt.subplots(figsize=(8,8))

title = "Curva de Nivel ROP"

plt.title(title,fontsize=25)
ttl = ax.title
ttl.set_position([0.5,1.05])

sns.heatmap(Tabla,xticklabels=10,yticklabels=10,cmap="seismic", ax=ax,
            cbar_kws={"shrink": 0.8, "label":" ROP (ft/hr)","orientation": "horizontal"},
            annot_kws={'size':5}
           )
plt.ylim(0,40)
plt.xlim(1,60);
